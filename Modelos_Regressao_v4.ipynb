# %% [markdown]
# <a href="https://colab.research.google.com/github/Renata-Thomazelli/mentoria2021/blob/main/Modelos_Regressao_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise Exploratória de Dados

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## Verificando e limpando o dataset

# %%
dados = pd.read_csv('dataset.csv')
dados
# Out:
#     Unnamed: 0  AREA_AGRI_AUS  AREA_AGRI_BRA  AREA_AGRI_CAN  AREA_AGRI_CHN  \
# 0            0      60.896151      27.373333       6.839325      53.422560
# 1            1      61.763332      18.779178       6.897817      36.420045
# 2            2      62.037792      19.222698       6.946559      36.712150
# 3            3      62.399227      19.666218       6.995301      37.014865
# 4            4      62.729106      20.109737       7.044043      37.317474
# ..         ...            ...            ...            ...            ...
# 56          56      44.539926      28.254971       6.474755      56.081665
# 57          57      48.340618      28.341066       6.471855      56.079351
# 58          58      46.658095      28.341090       6.491374      56.079083
# 59          59      60.896151      27.373333       6.839325      53.422560
# 60          60      60.896151      27.373333       6.839325      53.422560
#
#     AREA_AGRI_DEU  AREA_AGRI_EGY  AREA_AGRI_FRA  AREA_AGRI_GBR  AREA_AGRI_IDN  \
# 0       51.682754       2.866543      56.005760      74.965899      23.180722
# 1       55.495088       2.579738      63.077328      81.841855      21.307485
# 2       55.546645       2.516450      62.896528      81.755053      21.307485
# 3       55.572423       2.501381      62.739469      81.622783      21.279884
# 4       55.732822       2.517454      62.292034      81.440913      21.279884
# ..            ...            ...            ...            ...            ...
# 56      47.678612       3.750832      52.447546      71.714884      32.063590
# 57      47.763116       3.853502      52.410067      72.195067      33.182088
# 58      47.641536       3.853502      52.341765      71.718520      33.182088
# 59      51.682754       2.866543      56.005760      74.965899      23.180722
# 60      51.682754       2.866543      56.005760      74.965899      23.180722
#
#     ...  TRIGO_PROD_EGY  TRIGO_PROD_IND  TRIGO_PROD_IDN  TRIGO_PROD_PHL  \
# 0   ...            1499           10320               0               0
# 1   ...            1436           10995               0               0
# 2   ...            1593           12076               0               0
# 3   ...            1493           10779               0               0
# 4   ...            1500            9854               0               0
# ..  ...             ...             ...             ...             ...
# 56  ...            8100           87000               0               0
# 57  ...            8450           98510               0               0
# 58  ...            8450           99870               0               0
# 59  ...            8770          103600               0               0
# 60  ...            8900          107860               0               0
#
#     TRIGO_PROD_RUS  TRIGO_PROD_TUR  TRIGO_PROD_GBR  TRIGO_PROD_USA  \
# 0                0            7000               0           36877
# 1                0            6336               0           33557
# 2                0            6804               0           29719
# 3                0            7892               0           31216
# 4                0            7000               0           34917
# ..             ...             ...             ...             ...
# 56           72529           17250           14383           62832
# 57           85167           21000           14444           47380
# 58           71685           19000           13455           51306
# 59           73610           17500           15600           52581
# 60           85354           18250            9658           49691
#
#     PRECO_PETROLEO  TRIGO_PRECO
# 0             2.88       1.9554
# 1             2.89       2.0091
# 2             2.89       2.0897
# 3             2.89       2.0022
# 4             2.88       1.6820
# ..             ...          ...
# 56           38.29       4.3945
# 57           48.05       4.4014
# 58           61.40       4.9757
# 59           55.59       4.9414
# 60           36.86       5.4980
#
# [61 rows x 198 columns]

# %%
#dados.columns.values[0] = 'Ano_n'
dados.drop(columns='Unnamed: 0', inplace=True)
dados
# Out:
#     AREA_AGRI_AUS  AREA_AGRI_BRA  AREA_AGRI_CAN  AREA_AGRI_CHN  AREA_AGRI_DEU  \
# 0       60.896151      27.373333       6.839325      53.422560      51.682754
# 1       61.763332      18.779178       6.897817      36.420045      55.495088
# 2       62.037792      19.222698       6.946559      36.712150      55.546645
# 3       62.399227      19.666218       6.995301      37.014865      55.572423
# 4       62.729106      20.109737       7.044043      37.317474      55.732822
# ..            ...            ...            ...            ...            ...
# 56      44.539926      28.254971       6.474755      56.081665      47.678612
# 57      48.340618      28.341066       6.471855      56.079351      47.763116
# 58      46.658095      28.341090       6.491374      56.079083      47.641536
# 59      60.896151      27.373333       6.839325      53.422560      51.682754
# 60      60.896151      27.373333       6.839325      53.422560      51.682754
#
#     AREA_AGRI_EGY  AREA_AGRI_FRA  AREA_AGRI_GBR  AREA_AGRI_IDN  AREA_AGRI_IND  \
# 0        2.866543      56.005760      74.965899      23.180722      60.536663
# 1        2.579738      63.077328      81.841855      21.307485      58.843195
# 2        2.516450      62.896528      81.755053      21.307485      59.357794
# 3        2.501381      62.739469      81.622783      21.279884      59.247475
# 4        2.517454      62.292034      81.440913      21.279884      59.435152
# ..            ...            ...            ...            ...            ...
# 56       3.750832      52.447546      71.714884      32.063590      60.431389
# 57       3.853502      52.410067      72.195067      33.182088      60.431389
# 58       3.853502      52.341765      71.718520      33.182088      60.431389
# 59       2.866543      56.005760      74.965899      23.180722      60.536663
# 60       2.866543      56.005760      74.965899      23.180722      60.536663
#
#     ...  TRIGO_PROD_EGY  TRIGO_PROD_IND  TRIGO_PROD_IDN  TRIGO_PROD_PHL  \
# 0   ...            1499           10320               0               0
# 1   ...            1436           10995               0               0
# 2   ...            1593           12076               0               0
# 3   ...            1493           10779               0               0
# 4   ...            1500            9854               0               0
# ..  ...             ...             ...             ...             ...
# 56  ...            8100           87000               0               0
# 57  ...            8450           98510               0               0
# 58  ...            8450           99870               0               0
# 59  ...            8770          103600               0               0
# 60  ...            8900          107860               0               0
#
#     TRIGO_PROD_RUS  TRIGO_PROD_TUR  TRIGO_PROD_GBR  TRIGO_PROD_USA  \
# 0                0            7000               0           36877
# 1                0            6336               0           33557
# 2                0            6804               0           29719
# 3                0            7892               0           31216
# 4                0            7000               0           34917
# ..             ...             ...             ...             ...
# 56           72529           17250           14383           62832
# 57           85167           21000           14444           47380
# 58           71685           19000           13455           51306
# 59           73610           17500           15600           52581
# 60           85354           18250            9658           49691
#
#     PRECO_PETROLEO  TRIGO_PRECO
# 0             2.88       1.9554
# 1             2.89       2.0091
# 2             2.89       2.0897
# 3             2.89       2.0022
# 4             2.88       1.6820
# ..             ...          ...
# 56           38.29       4.3945
# 57           48.05       4.4014
# 58           61.40       4.9757
# 59           55.59       4.9414
# 60           36.86       5.4980
#
# [61 rows x 197 columns]

# %%
# Incluindo uma variável dummy com o número sequencial da observação, representando a passagem do tempo
ANO_N = pd.Series([n for n in range(61)])
ANO_N.name = 'ANO_N'
ANO_N
# Out:
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#       ..
# 56    56
# 57    57
# 58    58
# 59    59
# 60    60
# Name: ANO_N, Length: 61, dtype: int64

# %%
dados = pd.concat([ANO_N, dados], axis=1)
dados
# Out:
#     ANO_N  AREA_AGRI_AUS  AREA_AGRI_BRA  AREA_AGRI_CAN  AREA_AGRI_CHN  \
# 0       0      60.896151      27.373333       6.839325      53.422560
# 1       1      61.763332      18.779178       6.897817      36.420045
# 2       2      62.037792      19.222698       6.946559      36.712150
# 3       3      62.399227      19.666218       6.995301      37.014865
# 4       4      62.729106      20.109737       7.044043      37.317474
# ..    ...            ...            ...            ...            ...
# 56     56      44.539926      28.254971       6.474755      56.081665
# 57     57      48.340618      28.341066       6.471855      56.079351
# 58     58      46.658095      28.341090       6.491374      56.079083
# 59     59      60.896151      27.373333       6.839325      53.422560
# 60     60      60.896151      27.373333       6.839325      53.422560
#
#     AREA_AGRI_DEU  AREA_AGRI_EGY  AREA_AGRI_FRA  AREA_AGRI_GBR  AREA_AGRI_IDN  \
# 0       51.682754       2.866543      56.005760      74.965899      23.180722
# 1       55.495088       2.579738      63.077328      81.841855      21.307485
# 2       55.546645       2.516450      62.896528      81.755053      21.307485
# 3       55.572423       2.501381      62.739469      81.622783      21.279884
# 4       55.732822       2.517454      62.292034      81.440913      21.279884
# ..            ...            ...            ...            ...            ...
# 56      47.678612       3.750832      52.447546      71.714884      32.063590
# 57      47.763116       3.853502      52.410067      72.195067      33.182088
# 58      47.641536       3.853502      52.341765      71.718520      33.182088
# 59      51.682754       2.866543      56.005760      74.965899      23.180722
# 60      51.682754       2.866543      56.005760      74.965899      23.180722
#
#     ...  TRIGO_PROD_EGY  TRIGO_PROD_IND  TRIGO_PROD_IDN  TRIGO_PROD_PHL  \
# 0   ...            1499           10320               0               0
# 1   ...            1436           10995               0               0
# 2   ...            1593           12076               0               0
# 3   ...            1493           10779               0               0
# 4   ...            1500            9854               0               0
# ..  ...             ...             ...             ...             ...
# 56  ...            8100           87000               0               0
# 57  ...            8450           98510               0               0
# 58  ...            8450           99870               0               0
# 59  ...            8770          103600               0               0
# 60  ...            8900          107860               0               0
#
#     TRIGO_PROD_RUS  TRIGO_PROD_TUR  TRIGO_PROD_GBR  TRIGO_PROD_USA  \
# 0                0            7000               0           36877
# 1                0            6336               0           33557
# 2                0            6804               0           29719
# 3                0            7892               0           31216
# 4                0            7000               0           34917
# ..             ...             ...             ...             ...
# 56           72529           17250           14383           62832
# 57           85167           21000           14444           47380
# 58           71685           19000           13455           51306
# 59           73610           17500           15600           52581
# 60           85354           18250            9658           49691
#
#     PRECO_PETROLEO  TRIGO_PRECO
# 0             2.88       1.9554
# 1             2.89       2.0091
# 2             2.89       2.0897
# 3             2.89       2.0022
# 4             2.88       1.6820
# ..             ...          ...
# 56           38.29       4.3945
# 57           48.05       4.4014
# 58           61.40       4.9757
# 59           55.59       4.9414
# 60           36.86       5.4980
#
# [61 rows x 198 columns]

# %%
# Incluindo variáveis para verificar a autocorrelação com (t-1), (t-3) e (t-5)
dados['TRIGO_PRECO_T-1'] = dados['TRIGO_PRECO'].shift(periods=1)
dados['TRIGO_PRECO_T-3'] = dados['TRIGO_PRECO'].shift(periods=3)
dados['TRIGO_PRECO_T-5'] = dados['TRIGO_PRECO'].shift(periods=5)
dados
# Out:
#     ANO_N  AREA_AGRI_AUS  AREA_AGRI_BRA  AREA_AGRI_CAN  AREA_AGRI_CHN  \
# 0       0      60.896151      27.373333       6.839325      53.422560
# 1       1      61.763332      18.779178       6.897817      36.420045
# 2       2      62.037792      19.222698       6.946559      36.712150
# 3       3      62.399227      19.666218       6.995301      37.014865
# 4       4      62.729106      20.109737       7.044043      37.317474
# ..    ...            ...            ...            ...            ...
# 56     56      44.539926      28.254971       6.474755      56.081665
# 57     57      48.340618      28.341066       6.471855      56.079351
# 58     58      46.658095      28.341090       6.491374      56.079083
# 59     59      60.896151      27.373333       6.839325      53.422560
# 60     60      60.896151      27.373333       6.839325      53.422560
#
#     AREA_AGRI_DEU  AREA_AGRI_EGY  AREA_AGRI_FRA  AREA_AGRI_GBR  AREA_AGRI_IDN  \
# 0       51.682754       2.866543      56.005760      74.965899      23.180722
# 1       55.495088       2.579738      63.077328      81.841855      21.307485
# 2       55.546645       2.516450      62.896528      81.755053      21.307485
# 3       55.572423       2.501381      62.739469      81.622783      21.279884
# 4       55.732822       2.517454      62.292034      81.440913      21.279884
# ..            ...            ...            ...            ...            ...
# 56      47.678612       3.750832      52.447546      71.714884      32.063590
# 57      47.763116       3.853502      52.410067      72.195067      33.182088
# 58      47.641536       3.853502      52.341765      71.718520      33.182088
# 59      51.682754       2.866543      56.005760      74.965899      23.180722
# 60      51.682754       2.866543      56.005760      74.965899      23.180722
#
#     ...  TRIGO_PROD_PHL  TRIGO_PROD_RUS  TRIGO_PROD_TUR  TRIGO_PROD_GBR  \
# 0   ...               0               0            7000               0
# 1   ...               0               0            6336               0
# 2   ...               0               0            6804               0
# 3   ...               0               0            7892               0
# 4   ...               0               0            7000               0
# ..  ...             ...             ...             ...             ...
# 56  ...               0           72529           17250           14383
# 57  ...               0           85167           21000           14444
# 58  ...               0           71685           19000           13455
# 59  ...               0           73610           17500           15600
# 60  ...               0           85354           18250            9658
#
#     TRIGO_PROD_USA  PRECO_PETROLEO  TRIGO_PRECO  TRIGO_PRECO_T-1  \
# 0            36877            2.88       1.9554              NaN
# 1            33557            2.89       2.0091           1.9554
# 2            29719            2.89       2.0897           2.0091
# 3            31216            2.89       2.0022           2.0897
# 4            34917            2.88       1.6820           2.0022
# ..             ...             ...          ...              ...
# 56           62832           38.29       4.3945           5.0836
# 57           47380           48.05       4.4014           4.3945
# 58           51306           61.40       4.9757           4.4014
# 59           52581           55.59       4.9414           4.9757
# 60           49691           36.86       5.4980           4.9414
#
#     TRIGO_PRECO_T-3  TRIGO_PRECO_T-5
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3            1.9554              NaN
# 4            2.0091              NaN
# ..              ...              ...
# 56           6.8608           7.1443
# 57           5.8908           7.5412
# 58           5.0836           6.8608
# 59           4.3945           5.8908
# 60           4.4014           5.0836
#
# [61 rows x 201 columns]

# %%
# Verificando a existência de NA's
dados.isna().sum().sum()
# Out:
# 16

# %%
# Identificando onde estão estes 7 NA's
dados.isna().sum()[dados.isna().sum() > 0]
# Out:
# TEMP_MAX_CHN        1
# TRIGO_IMPORT_MAC    2
# TRIGO_IMPORT_TWN    2
# TRIGO_IMPORT_CHN    2
# TRIGO_PRECO_T-1     1
# TRIGO_PRECO_T-3     3
# TRIGO_PRECO_T-5     5
# dtype: int64

# %%
# Utilizando a interpolação linear para imputação de dados:
df = dados.interpolate(axis=0, limit_area=None, limit_direction='both')

# %%
# Verificando a existência de NA's
df.isna().sum().sum()
# Out:
# 0

# %%
# Excluindo atributos de valores zerados: TRIGO_PROD_IDN e TRIGO_PROD_PHL
df.drop(columns=['TRIGO_PROD_IDN', 'TRIGO_PROD_PHL'], inplace=True)

# %% [markdown]
# ## Matriz de Correlação

# %% [markdown]
# A correlação entre as variáveis pode ser abordada de diferentes formas, a partir de dois pontos de vista distintos: a correlação de atributos com a variável target (desejável para que se possa prever com maior precisão) e a correlação entre os atributos (indesejável, na medida que indica informações redundantes, que podem ser eliminadas do dataset). A correlação entre as variáveis será analisada nesta seção.

# %%
mat_corr = df.corr()
mat_corr
# Out:
#                     ANO_N  AREA_AGRI_AUS  AREA_AGRI_BRA  AREA_AGRI_CAN  \
# ANO_N            1.000000      -0.806876       0.715511      -0.797918
# AREA_AGRI_AUS   -0.806876       1.000000      -0.441192       0.878889
# AREA_AGRI_BRA    0.715511      -0.441192       1.000000      -0.624360
# AREA_AGRI_CAN   -0.797918       0.878889      -0.624360       1.000000
# AREA_AGRI_CHN    0.877527      -0.691355       0.858040      -0.732301
# ...                   ...            ...            ...            ...
# PRECO_PETROLEO   0.787301      -0.809282       0.503188      -0.843755
# TRIGO_PRECO      0.747055      -0.668445       0.588482      -0.782055
# TRIGO_PRECO_T-1  0.745311      -0.690876       0.595837      -0.811470
# TRIGO_PRECO_T-3  0.749480      -0.725396       0.606215      -0.858793
# TRIGO_PRECO_T-5  0.763263      -0.669904       0.595189      -0.795030
#
#                  AREA_AGRI_CHN  AREA_AGRI_DEU  AREA_AGRI_EGY  AREA_AGRI_FRA  \
# ANO_N                 0.877527      -0.899759       0.782136      -0.917855
# AREA_AGRI_AUS        -0.691355       0.813659      -0.872733       0.799476
# AREA_AGRI_BRA         0.858040      -0.758926       0.356327      -0.825042
# AREA_AGRI_CAN        -0.732301       0.800599      -0.702688       0.806245
# AREA_AGRI_CHN         1.000000      -0.953334       0.675849      -0.958085
# ...                        ...            ...            ...            ...
# PRECO_PETROLEO        0.627178      -0.711015       0.704858      -0.737222
# TRIGO_PRECO           0.626438      -0.666461       0.565184      -0.706266
# TRIGO_PRECO_T-1       0.629513      -0.662836       0.566289      -0.703962
# TRIGO_PRECO_T-3       0.637651      -0.692291       0.573289      -0.706105
# TRIGO_PRECO_T-5       0.633360      -0.649954       0.521660      -0.670078
#
#                  AREA_AGRI_GBR  AREA_AGRI_IDN  ...  TRIGO_PROD_IND  \
# ANO_N                -0.854675       0.834705  ...        0.990746
# AREA_AGRI_AUS         0.681896      -0.971821  ...       -0.784159
# AREA_AGRI_BRA        -0.814128       0.478250  ...        0.702219
# AREA_AGRI_CAN         0.685702      -0.857819  ...       -0.802671
# AREA_AGRI_CHN        -0.933073       0.730605  ...        0.873806
# ...                        ...            ...  ...             ...
# PRECO_PETROLEO       -0.618090       0.816159  ...        0.779573
# TRIGO_PRECO          -0.596755       0.664045  ...        0.739829
# TRIGO_PRECO_T-1      -0.611576       0.670194  ...        0.741041
# TRIGO_PRECO_T-3      -0.626550       0.686612  ...        0.751533
# TRIGO_PRECO_T-5      -0.592154       0.664503  ...        0.787087
#
#                  TRIGO_PROD_RUS  TRIGO_PROD_TUR  TRIGO_PROD_GBR  \
# ANO_N                  0.911193        0.927391        0.467328
# AREA_AGRI_AUS         -0.779524       -0.695678       -0.360717
# AREA_AGRI_BRA          0.553684        0.794377        0.183124
# AREA_AGRI_CAN         -0.711349       -0.706819       -0.343626
# AREA_AGRI_CHN          0.804644        0.889491        0.224779
# ...                         ...             ...             ...
# PRECO_PETROLEO         0.663488        0.655138        0.237152
# TRIGO_PRECO            0.624626        0.633621        0.214238
# TRIGO_PRECO_T-1        0.622137        0.675913        0.217988
# TRIGO_PRECO_T-3        0.617331        0.714584        0.353193
# TRIGO_PRECO_T-5        0.685761        0.686445        0.591069
#
#                  TRIGO_PROD_USA  PRECO_PETROLEO  TRIGO_PRECO  TRIGO_PRECO_T-1  \
# ANO_N                  0.490004        0.787301     0.747055         0.745311
# AREA_AGRI_AUS         -0.204439       -0.809282    -0.668445        -0.690876
# AREA_AGRI_BRA          0.783730        0.503188     0.588482         0.595837
# AREA_AGRI_CAN         -0.397101       -0.843755    -0.782055        -0.811470
# AREA_AGRI_CHN          0.612415        0.627178     0.626438         0.629513
# ...                         ...             ...          ...              ...
# PRECO_PETROLEO         0.343072        1.000000     0.872541         0.821841
# TRIGO_PRECO            0.475353        0.872541     1.000000         0.883210
# TRIGO_PRECO_T-1        0.559546        0.821841     0.883210         1.000000
# TRIGO_PRECO_T-3        0.429189        0.708146     0.657491         0.728207
# TRIGO_PRECO_T-5        0.344337        0.625264     0.590521         0.638653
#
#                  TRIGO_PRECO_T-3  TRIGO_PRECO_T-5
# ANO_N                   0.749480         0.763263
# AREA_AGRI_AUS          -0.725396        -0.669904
# AREA_AGRI_BRA           0.606215         0.595189
# AREA_AGRI_CAN          -0.858793        -0.795030
# AREA_AGRI_CHN           0.637651         0.633360
# ...                          ...              ...
# PRECO_PETROLEO          0.708146         0.625264
# TRIGO_PRECO             0.657491         0.590521
# TRIGO_PRECO_T-1         0.728207         0.638653
# TRIGO_PRECO_T-3         1.000000         0.733256
# TRIGO_PRECO_T-5         0.733256         1.000000
#
# [199 rows x 199 columns]

# %%
# Correlação entre a variável target e os atributos
mat_corr['TRIGO_PRECO']
# Out:
# ANO_N              0.747055
# AREA_AGRI_AUS     -0.668445
# AREA_AGRI_BRA      0.588482
# AREA_AGRI_CAN     -0.782055
# AREA_AGRI_CHN      0.626438
#                      ...
# PRECO_PETROLEO     0.872541
# TRIGO_PRECO        1.000000
# TRIGO_PRECO_T-1    0.883210
# TRIGO_PRECO_T-3    0.657491
# TRIGO_PRECO_T-5    0.590521
# Name: TRIGO_PRECO, Length: 199, dtype: float64

# %%
abs(mat_corr['TRIGO_PRECO']).plot();

# %% [markdown]
# Para evitar o overfitting em uma modelo de regressão, o ideal é reduzir ao máximo possível o número de variáveis no dataset que não tenham impacto significativo sobre a variável target.

# %%
mat_corr['TRIGO_PRECO'][abs(mat_corr['TRIGO_PRECO']) < 0.5].shape
# Out:
# (101,)

# %%
mat_corr = df.corr()

# %% [markdown]
# ## Redução de dimensionalidade - PCA

# %%
from sklearn import decomposition
from sklearn.preprocessing import MinMaxScaler

# %%
# Dividindo entradas e saída no dataset
#Y = df['TRIGO_PRECO'].values.reshape(1,-1)
Y = df['TRIGO_PRECO'].values

# %%
Entradas = {}
scaler = MinMaxScaler()

# %%
for i in range(5, 9):
    excluir = mat_corr['TRIGO_PRECO'][abs(mat_corr['TRIGO_PRECO']) < 0.1*i].index
    df_filt = df.drop(columns=excluir)
    
    X = df_filt.drop(columns=['TRIGO_PRECO'], axis=1).values
    X_scaled = scaler.fit_transform(X)
    Entradas[f'Filtro {10*i}%, sem PCA'] = X_scaled
    
    pca95 = decomposition.PCA(n_components=0.95)
    pca95.fit(X_scaled)
    Entradas[f'Filtro {10*i}%, PCA 95%'] = pca95.transform(X_scaled)
    
    pca99 = decomposition.PCA(n_components=0.99)
    pca99.fit(X_scaled)
    Entradas[f'Filtro {10*i}%, PCA 99%'] = pca99.transform(X_scaled)

# %% [markdown]
# # Criação dos Modelos de Regressão

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_squared_error

import warnings
warnings.simplefilter("ignore")

# %%
modelos = {'Regressão Linear': LinearRegression(), 'Ridge': Ridge(), 
           'Lasso': Lasso(), 'ElasticNet': ElasticNet(), 'KNN Regressor': KNeighborsRegressor(),
           'DecisionTree Regressor': DecisionTreeRegressor(), 'SVR': SVR()}

# %%
result = {'Modelo': [], 'Dados': [], 'r2 total': [], 'mse': []}

# %%
for key in modelos:
    for ch in Entradas:
        # Treinando o modelo
        modelos[key].fit(Entradas[ch], Y)
        
        # Fazendo previsões
        Y_pred = modelos[key].predict(Entradas[ch])
        
        # Resultado
        r2 = r2_score(Y, Y_pred)
        mse = mean_squared_error(Y, Y_pred)
        
        #print(f'Modelo: {key}; Dados: {ch}; r2 total: {r2}; mse: {mse}')
        result['Modelo'].append(key)
        result['Dados'].append(ch)
        result['r2 total'].append(r2)
        result['mse'].append(mse)

resultados = pd.DataFrame.from_dict(result)
resultados
# Out:
#               Modelo                Dados  r2 total           mse
# 0   Regressão Linear  Filtro 50%, sem PCA  1.000000  1.692575e-29
# 1   Regressão Linear  Filtro 50%, PCA 95%  0.858115  3.462582e-01
# 2   Regressão Linear  Filtro 50%, PCA 99%  0.945916  1.319874e-01
# 3   Regressão Linear  Filtro 60%, sem PCA  1.000000  7.291564e-28
# 4   Regressão Linear  Filtro 60%, PCA 95%  0.823279  4.312723e-01
# ..               ...                  ...       ...           ...
# 79               SVR  Filtro 70%, PCA 95%  0.793549  5.038262e-01
# 80               SVR  Filtro 70%, PCA 99%  0.834515  4.038519e-01
# 81               SVR  Filtro 80%, sem PCA  0.891840  2.639547e-01
# 82               SVR  Filtro 80%, PCA 95%  0.861411  3.382153e-01
# 83               SVR  Filtro 80%, PCA 99%  0.882809  2.859943e-01
#
# [84 rows x 4 columns]

# %%
# Excluindo os resultados com r2 = 1, claramente com overfitting
resultados[resultados['r2 total']!=1].sort_values(by='r2 total', ascending=False).head(20)
# Out:
#               Modelo                Dados  r2 total       mse
# 6   Regressão Linear  Filtro 70%, sem PCA  0.983018  0.041444
# 2   Regressão Linear  Filtro 50%, PCA 99%  0.945916  0.131987
# 12             Ridge  Filtro 50%, sem PCA  0.943682  0.137440
# 14             Ridge  Filtro 50%, PCA 99%  0.929359  0.172393
# 15             Ridge  Filtro 60%, sem PCA  0.923292  0.187200
# 5   Regressão Linear  Filtro 60%, PCA 99%  0.921756  0.190949
# 17             Ridge  Filtro 60%, PCA 99%  0.906132  0.229078
# 9   Regressão Linear  Filtro 80%, sem PCA  0.902365  0.238270
# 55     KNN Regressor  Filtro 70%, PCA 95%  0.898881  0.246773
# 51     KNN Regressor  Filtro 60%, sem PCA  0.898355  0.248056
# 53     KNN Regressor  Filtro 60%, PCA 99%  0.896149  0.253440
# 56     KNN Regressor  Filtro 70%, PCA 99%  0.896030  0.253731
# 52     KNN Regressor  Filtro 60%, PCA 95%  0.894248  0.258080
# 57     KNN Regressor  Filtro 80%, sem PCA  0.893021  0.261073
# 54     KNN Regressor  Filtro 70%, sem PCA  0.892546  0.262233
# 81               SVR  Filtro 80%, sem PCA  0.891840  0.263955
# 8   Regressão Linear  Filtro 70%, PCA 99%  0.887100  0.275523
# 59     KNN Regressor  Filtro 80%, PCA 99%  0.885499  0.279431
# 50     KNN Regressor  Filtro 50%, PCA 99%  0.884702  0.281376
# 48     KNN Regressor  Filtro 50%, sem PCA  0.884113  0.282813
